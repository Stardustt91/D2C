# %%
import cost_driver
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1256\2207814739.py in ?()
# ----> 1 import cost_driver
#
# c:\Users\AtefY\Desktop\projects\d2c_new\agents\cost_driver.py in ?()
#      31 #     embeddings,
#      32 #     allow_dangerous_deserialization=True
#      33 # )
#      34
# ---> 35 drivers_db = FAISS.load_local(
#      36     "new_vector_dbs/cost_drivers_faiss",
#      37     embeddings,
#      38     allow_dangerous_deserialization=True
#
# c:\Users\AtefY\AppData\Local\anaconda3\Lib\site-packages\langchain_community\vectorstores\faiss.py in ?(cls, folder_path, embeddings, index_name, allow_dangerous_deserialization, **kwargs)
#    1201             )
#    1202         path = Path(folder_path)
#    1203         # load index separately since it is not picklable
#    1204         faiss = dependable_faiss_import()
# ...
